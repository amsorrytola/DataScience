# %%
import pandas as pd

# %%
dataset = pd.read_csv("JSTdatasetR6.csv")
dataset.isnull().sum()
# Out:
# year                           0
# country                        0
# iso                            0
# ifs                            0
# pop                           51
# rgdpmad                       52
# rgdpbarro                     54
# rconsbarro                   157
# gdp                           77
# iy                           293
# cpi                           52
# ca                           229
# imports                      115
# exports                      115
# narrowm                      114
# money                        200
# stir                         198
# ltrate                        88
# hpnom                        668
# unemp                        769
# wage                          88
# debtgdp                      229
# revenue                      176
# expenditure                  157
# xrusd                         53
# tloans                       253
# tmort                        406
# thh                         1344
# tbus                        1419
# bdebt                        853
# lev                          365
# ltd                          419
# noncore                      488
# crisisJST                     50
# crisisJST_old                150
# peg                           50
# peg_strict                    50
# peg_type                      50
# peg_base                     253
# JSTtrilemmaIV                645
# eq_tr                        455
# housing_tr                   809
# bond_tr                      423
# bill_rate                    367
# rent_ipolated               2689
# housing_capgain_ipolated    2713
# housing_capgain              673
# housing_rent_rtn             809
# housing_rent_yd              797
# eq_capgain                   548
# eq_dp                        549
# eq_capgain_interp           2711
# eq_tr_interp                2711
# eq_dp_interp                2712
# bond_rate                    337
# eq_div_rtn                   555
# capital_tr                   888
# risky_tr                     864
# safe_tr                      471
# dtype: int64

# %%
dataset.shape
# Out:
# (2718, 59)

# %%
(dataset.isnull().sum()/dataset.shape[0])*100
# Out:
# year                         0.000000
# country                      0.000000
# iso                          0.000000
# ifs                          0.000000
# pop                          1.876380
# rgdpmad                      1.913171
# rgdpbarro                    1.986755
# rconsbarro                   5.776306
# gdp                          2.832965
# iy                          10.779985
# cpi                          1.913171
# ca                           8.425313
# imports                      4.231052
# exports                      4.231052
# narrowm                      4.194260
# money                        7.358352
# stir                         7.284768
# ltrate                       3.237675
# hpnom                       24.576895
# unemp                       28.292862
# wage                         3.237675
# debtgdp                      8.425313
# revenue                      6.475350
# expenditure                  5.776306
# xrusd                        1.949963
# tloans                       9.308315
# tmort                       14.937454
# thh                         49.448124
# tbus                        52.207506
# bdebt                       31.383370
# lev                         13.428992
# ltd                         15.415747
# noncore                     17.954378
# crisisJST                    1.839588
# crisisJST_old                5.518764
# peg                          1.839588
# peg_strict                   1.839588
# peg_type                     1.839588
# peg_base                     9.308315
# JSTtrilemmaIV               23.730684
# eq_tr                       16.740250
# housing_tr                  29.764533
# bond_tr                     15.562914
# bill_rate                   13.502575
# rent_ipolated               98.933039
# housing_capgain_ipolated    99.816041
# housing_capgain             24.760854
# housing_rent_rtn            29.764533
# housing_rent_yd             29.323032
# eq_capgain                  20.161884
# eq_dp                       20.198675
# eq_capgain_interp           99.742458
# eq_tr_interp                99.742458
# eq_dp_interp                99.779249
# bond_rate                   12.398823
# eq_div_rtn                  20.419426
# capital_tr                  32.671082
# risky_tr                    31.788079
# safe_tr                     17.328918
# dtype: float64

# %%
#Empty data
(dataset.isnull().sum().sum()/(dataset.shape[0]*dataset.shape[1]))*100
# Out:
# np.float64(20.460582931118346)

# %%
#Deleting columns with more than 30% missing values
dataset = dataset.loc[:, (dataset.isnull().sum() / dataset.shape[0]) * 100 <= 30]

# %%
(dataset.isnull().sum()/dataset.shape[0])*100
# Out:
# year                 0.000000
# country              0.000000
# iso                  0.000000
# ifs                  0.000000
# pop                  1.876380
# rgdpmad              1.913171
# rgdpbarro            1.986755
# rconsbarro           5.776306
# gdp                  2.832965
# iy                  10.779985
# cpi                  1.913171
# ca                   8.425313
# imports              4.231052
# exports              4.231052
# narrowm              4.194260
# money                7.358352
# stir                 7.284768
# ltrate               3.237675
# hpnom               24.576895
# unemp               28.292862
# wage                 3.237675
# debtgdp              8.425313
# revenue              6.475350
# expenditure          5.776306
# xrusd                1.949963
# tloans               9.308315
# tmort               14.937454
# lev                 13.428992
# ltd                 15.415747
# noncore             17.954378
# crisisJST            1.839588
# crisisJST_old        5.518764
# peg                  1.839588
# peg_strict           1.839588
# peg_type             1.839588
# peg_base             9.308315
# JSTtrilemmaIV       23.730684
# eq_tr               16.740250
# housing_tr          29.764533
# bond_tr             15.562914
# bill_rate           13.502575
# housing_capgain     24.760854
# housing_rent_rtn    29.764533
# housing_rent_yd     29.323032
# eq_capgain          20.161884
# eq_dp               20.198675
# bond_rate           12.398823
# eq_div_rtn          20.419426
# safe_tr             17.328918
# dtype: float64

# %%
(dataset.isnull().sum().sum()/(dataset.shape[0]*dataset.shape[1]))*100
# Out:
# np.float64(10.442101785526573)

# %%
sns.heatmap(dataset.isnull())
# Out:
# <Axes: >

# %%
dataset.fillna(method='bfill',inplace=True)
sns.heatmap(dataset.isnull())
# Out:
# /tmp/ipykernel_7082/1115243020.py:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   dataset.fillna(method='bfill',inplace=True)
# <Axes: >
